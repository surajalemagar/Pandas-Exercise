# %% [markdown]
# # Grouping Data

# %%
import pandas as pd

# %%
data=pd.read_csv("CSV Folder/analysis-assualt.csv")

# %%
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
data.columns
# Out:
# Index(['Index', 'Area_unit_2013_code', 'Area_unit_2013_label',
#        'Victimisations_calendar_year_2015', 'Population_mid_point_2015',
#        ' Rate_per_10000_population ', ' Rate_ratio_NZ_average_rate ',
#        'Urban_area_2013_code', 'Urban_area_2013_label', 'Urban_area_type',
#        'Territorial_authority_area_2013_code',
#        'Territorial_authority_area_2013_label', 'Region_2013_code',
#        'Region_2013_label'],
#       dtype='object')

# %%
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
group_by_urban=data.groupby('Urban_area_type')

# %%
group_by_urban.get_group('Rural area')
# Out:
#       Index  Area_unit_2013_code   Area_unit_2013_label  \
# 74       75               587904            West Melton
# 365     366               533603                 Hikuai
# 370     371               501806  Marsden Point-Ruakaka
# 414     415               536630                 Kaimai
# 415     416               521122               Kingseat
# ...     ...                  ...                    ...
# 2004   2005               585807                 Loburn
# 2006   2007               551111              Lepperton
# 2011   2012               610040                Hokonui
# 2012   2013               586603             Mandeville
# 2015   2016               506653              Riverhead
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 74                                   52                       8470
# 365                                  18                       3410
# 370                                  18                       4010
# ...

# %%
data['Urban_area_type'].unique()
# Out:
# array(['Main urban area', 'Secondary urban area', 'Minor urban area',
#        'Rural area'], dtype=object)

# %%
group_data=data.groupby('Urban_area_type')

# %%
group_data.get_group('Rural area')
# Out:
#       Index  Area_unit_2013_code   Area_unit_2013_label  \
# 74       75               587904            West Melton
# 365     366               533603                 Hikuai
# 370     371               501806  Marsden Point-Ruakaka
# 414     415               536630                 Kaimai
# 415     416               521122               Kingseat
# ...     ...                  ...                    ...
# 2004   2005               585807                 Loburn
# 2006   2007               551111              Lepperton
# 2011   2012               610040                Hokonui
# 2012   2013               586603             Mandeville
# 2015   2016               506653              Riverhead
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 74                                   52                       8470
# 365                                  18                       3410
# 370                                  18                       4010
# ...

# %%
group_data.get_group('Rural area')
# Out:
#       Index  Area_unit_2013_code   Area_unit_2013_label  \
# 74       75               587904            West Melton
# 365     366               533603                 Hikuai
# 370     371               501806  Marsden Point-Ruakaka
# 414     415               536630                 Kaimai
# 415     416               521122               Kingseat
# ...     ...                  ...                    ...
# 2004   2005               585807                 Loburn
# 2006   2007               551111              Lepperton
# 2011   2012               610040                Hokonui
# 2012   2013               586603             Mandeville
# 2015   2016               506653              Riverhead
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 74                                   52                       8470
# 365                                  18                       3410
# 370                                  18                       4010
# ...

# %%
len(group_data.get_group('Rural area'))
# Out:
# 640

# %%
group_data.size()
# Out:
# Urban_area_type
# Main urban area         1112
# Minor urban area         137
# Rural area               640
# Secondary urban area     131
# dtype: int64

# %%
group_data.first()
# Out:
#                       Index  Area_unit_2013_code   Area_unit_2013_label  \
# Urban_area_type
# Main urban area           1               514102  Auckland Central West
# Minor urban area         48               501700                Kaikohe
# Rural area               75               587904            West Melton
# Secondary urban area     17               609302        Queenstown Hill
#
#                       Victimisations_calendar_year_2015  \
# Urban_area_type
# Main urban area                                     550
# Minor urban area                                     68
# Rural area                                           52
# Secondary urban area                                113
#
#                       Population_mid_point_2015  Rate_per_10000_population   \
# Urban_area_type
# Main urban area                           15900                         346
# Minor urban area                           4370                         156
# ...

# %%
group_data.sum()
# Out:
#                        Index  Area_unit_2013_code  \
# Urban_area_type
# Main urban area       902131            611235607
# Minor urban area       98463             76699437
# Rural area            916111            365328272
# Secondary urban area  124505             74523259
#
#                       Victimisations_calendar_year_2015  \
# Urban_area_type
# Main urban area                                   18991
# Minor urban area                                   1989
# Rural area                                         1349
# Secondary urban area                               1706
#
#                       Population_mid_point_2015  Urban_area_2013_code  \
# Urban_area_type
# Main urban area                         3349420                 13701
# Minor urban area                         363800                 35149
# Rural area                               625870                321809
# Secondary urban area                     256360                 14179
#
# ...

# %%
group_data.sum()
# Out:
#                        Index  Area_unit_2013_code  \
# Urban_area_type
# Main urban area       902131            611235607
# Minor urban area       98463             76699437
# Rural area            916111            365328272
# Secondary urban area  124505             74523259
#
#                       Victimisations_calendar_year_2015  \
# Urban_area_type
# Main urban area                                   18991
# Minor urban area                                   1989
# Rural area                                         1349
# Secondary urban area                               1706
#
#                       Population_mid_point_2015  Urban_area_2013_code  \
# Urban_area_type
# Main urban area                         3349420                 13701
# Minor urban area                         363800                 35149
# Rural area                               625870                321809
# Secondary urban area                     256360                 14179
#
# ...

# %%
group_data.get_group('Rural area')['Index'].min()
# Out:
# 75

# %%
group_data.sum()[['Index','Area_unit_2013_code']]
group_data.sum()[{'Index':['sum','mean'],'Area_unit_2013_code':'mean'}]
# Out:
#                        Index  Area_unit_2013_code
# Urban_area_type
# Main urban area       902131            611235607
# Minor urban area       98463             76699437
# Rural area            916111            365328272
# Secondary urban area  124505             74523259

# %%
group_data.agg(['sum','mean'])[['Index','Area_unit_2013_code']]
# Out:
#                        Index              Area_unit_2013_code
#                          sum         mean                 sum           mean
# Urban_area_type
# Main urban area       902131   811.268885           611235607  549672.308453
# Minor urban area       98463   718.708029            76699437  559849.905109
# Rural area            916111  1431.423438           365328272  570825.425000
# Secondary urban area  124505   950.419847            74523259  568879.839695

# %%
dic={'Index':'sum','Area_unit_2013_code':'mean'}
group_data.agg(dic)
# Out:
#                        Index  Area_unit_2013_code
# Urban_area_type
# Main urban area       902131        549672.308453
# Minor urban area       98463        559849.905109
# Rural area            916111        570825.425000
# Secondary urban area  124505        568879.839695

# %%
group_data.get_group('Rural area').sum()
# Out:
# Index                                                                               916111
# Area_unit_2013_code                                                              365328272
# Area_unit_2013_label                     West MeltonHikuaiMarsden Point-RuakakaKaimaiKi...
# Victimisations_calendar_year_2015                                                     1349
# Population_mid_point_2015                                                           625870
#  Rate_per_10000_population               6153453025816051403450451575239363323191163836...
#  Rate_ratio_NZ_average_rate              1.210.90.60.51.51.110.80.610.9310.80.70.60.40....
# Urban_area_2013_code                                                                321809
# Urban_area_2013_label                    Rural (Incl.some Off Shore Islands)Rural (Incl...
# Territorial_authority_area_2013_code                                                 72645
# ...

# %%
group_data.sum()
# Out:
#                        Index  Area_unit_2013_code  \
# Urban_area_type
# Main urban area       902131            611235607
# Minor urban area       98463             76699437
# Rural area            916111            365328272
# Secondary urban area  124505             74523259
#
#                       Victimisations_calendar_year_2015  \
# Urban_area_type
# Main urban area                                   18991
# Minor urban area                                   1989
# Rural area                                         1349
# Secondary urban area                               1706
#
#                       Population_mid_point_2015  Urban_area_2013_code  \
# Urban_area_type
# Main urban area                         3349420                 13701
# Minor urban area                         363800                 35149
# Rural area                               625870                321809
# Secondary urban area                     256360                 14179
#
# ...

# %%
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
for i in range(len(data['Urban_area_type'])):
    if data['Urban_area_type'][i]=='Rural area':
        data['Urban_area_type'][i]='yes'
    else:
        data['Urban_area_type'][i]='no'
# Out:
# C:\Users\SURAJ ALE\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\SURAJ ALE\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
len(data['Urban_area_type'])
# Out:
# 2020

# %%
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
y_n=data.groupby('Urban_area_type')

# %%
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2014   2015               573514               Churton Park South
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# 3         4               514103            Auckland Central East
# 4         5               591500                 Cathedral Square
# ...     ...                  ...                              ...
# 2015   2016               506653                        Riverhead
# 2016   2017               610601                         Grasmere
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# ...

# %%
pd.set_option('max_rows',7)

# %%
data
# Out:
#       Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0         1               514102            Auckland Central West
# 1         2               573101  Willis Street-Cambridge Terrace
# 2         3               529700                 Hamilton Central
# ...     ...                  ...                              ...
# 2017   2018               536513                   Bethlehem East
# 2018   2019               574302                        Te Kainga
# 2019   2020               527007                    Horsham Downs
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# 1                                   447                       8300
# 2                                   380                       3170
# ...                                 ...                        ...
# 2017                                  0                       3590
# ...

# %%
data['Region_2013_label'].unique()
# Out:
# array(['Auckland Region', 'Wellington Region', 'Waikato Region',
#        'Canterbury Region', 'Manawatu-Wanganui Region',
#        'Bay of Plenty Region', 'Otago Region', 'Nelson Region',
#        "Hawke's Bay Region", 'Gisborne Region', 'Taranaki Region',
#        'Marlborough Region', 'Northland Region', 'Southland Region',
#        'Tasman Region', 'West Coast Region', 'Area Outside Region'],
#       dtype=object)

# %%
suraj_data=data.groupby('Region_2013_label')

# %%
suraj_data

# %%
max_Area_unit_2013_code=data[data['Area_unit_2013_code']==suraj_data.get_group('Otago Region')['Area_unit_2013_code'].max()]

# %%
max_Area_unit_2013_code
# Out:
#       Index  Area_unit_2013_code Area_unit_2013_label  \
# 1694   1695               626000    Inlet-Port Oamaru
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 1694                                  0                          0
#
#       Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 1694                        -                            -
#
#       Urban_area_2013_code              Urban_area_2013_label Urban_area_type  \
# 1694                   507  Inlet-in TA but not in Urban Area      Rural area
#
#       Territorial_authority_area_2013_code  \
# 1694                                    68
#
#      Territorial_authority_area_2013_label  Region_2013_code Region_2013_label
# 1694                      Waitaki District                14      Otago Region

# %%
suraj_data.get_group
# Out:
# <bound method _GroupBy.get_group of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0EB51930>>

# %%
r=suraj_data.get_group('Auckland Region')

# %%
r
# Out:
#       Index  Area_unit_2013_code   Area_unit_2013_label  \
# 0         1               514102  Auckland Central West
# 3         4               514103  Auckland Central East
# 5         6               514101   Auckland Harbourside
# ...     ...                  ...                    ...
# 2008   2009               512801              Laingholm
# 2009   2010               507500          Campbells Bay
# 2015   2016               506653              Riverhead
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# 3                                   375                      13250
# 5                                   253                       5680
# ...                                 ...                        ...
# 2008                                  0                       2620
# 2009                                  0                       2630
# ...

# %%
suraj=r.groupby('Urban_area_type')

# %%
rr=suraj.get_group('Rural area')
rr
# Out:
#       Index  Area_unit_2013_code Area_unit_2013_label  \
# 415     416               521122             Kingseat
# 492     493               513800             Karekare
# 578     579               506661    Cape Rodney South
# ...     ...                  ...                  ...
# 1918   1919               506656       Waitakere West
# 1966   1967               506654        Muriwai Beach
# 2015   2016               506653            Riverhead
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 415                                  17                       6670
# 492                                  14                       2760
# 578                                  11                       3070
# ...                                 ...                        ...
# 1918                                  0                        650
# 1966                                  0                       1220
# ...

# %%
ans=rr[rr['Area_unit_2013_code']==rr['Area_unit_2013_code'].min()]

# %%
ans
# Out:
#       Index  Area_unit_2013_code Area_unit_2013_label  \
# 1878   1879               505400                Leigh
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 1878                                  0                        470
#
#       Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 1878                        -                            -
#
#       Urban_area_2013_code Urban_area_2013_label Urban_area_type  \
# 1878                   501          Rural Centre      Rural area
#
#       Territorial_authority_area_2013_code  \
# 1878                                    76
#
#      Territorial_authority_area_2013_label  Region_2013_code Region_2013_label
# 1878                              Auckland                 2   Auckland Region

# %%
rr
# Out:
#       Index  Area_unit_2013_code Area_unit_2013_label  \
# 415     416               521122             Kingseat
# 492     493               513800             Karekare
# 578     579               506661    Cape Rodney South
# ...     ...                  ...                  ...
# 1918   1919               506656       Waitakere West
# 1966   1967               506654        Muriwai Beach
# 2015   2016               506653            Riverhead
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 415                                  17                       6670
# 492                                  14                       2760
# 578                                  11                       3070
# ...                                 ...                        ...
# 1918                                  0                        650
# 1966                                  0                       1220
# ...

# %%
r
# Out:
#       Index  Area_unit_2013_code   Area_unit_2013_label  \
# 0         1               514102  Auckland Central West
# 3         4               514103  Auckland Central East
# 5         6               514101   Auckland Harbourside
# ...     ...                  ...                    ...
# 2008   2009               512801              Laingholm
# 2009   2010               507500          Campbells Bay
# 2015   2016               506653              Riverhead
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                   550                      15900
# 3                                   375                      13250
# 5                                   253                       5680
# ...                                 ...                        ...
# 2008                                  0                       2620
# 2009                                  0                       2630
# ...

# %%
ans
# Out:
#       Index  Area_unit_2013_code Area_unit_2013_label  \
# 1878   1879               505400                Leigh
#
#       Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 1878                                  0                        470
#
#       Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 1878                        -                            -
#
#       Urban_area_2013_code Urban_area_2013_label Urban_area_type  \
# 1878                   501          Rural Centre      Rural area
#
#       Territorial_authority_area_2013_code  \
# 1878                                    76
#
#      Territorial_authority_area_2013_label  Region_2013_code Region_2013_label
# 1878                              Auckland                 2   Auckland Region

# %%
suraj_data.agg(['sum','mean'])[['Index','Area_unit_2013_code']]
# Out:
#                        Index              Area_unit_2013_code
#                          sum         mean                 sum           mean
# Region_2013_label
# Area Outside Region    31979  1683.105263            12115406  637652.947368
# Auckland Region       351263   803.805492           228136920  522052.448513
# Bay of Plenty Region  116270   901.317829            69921421  542026.519380
# ...                      ...          ...                 ...            ...
# Waikato Region        214201  1024.885167           112175975  536727.153110
# Wellington Region     221263  1038.793427           121963800  572600.000000
# West Coast Region      85282  1496.175439            33421322  586338.982456
#
# [17 rows x 4 columns]
