# %% [markdown]
# # Exercise

# %%
import pandas as pd
import numpy as np

# %%
suraj=pd.read_csv("CSV Folder/googleplaystore.csv")

# %%
suraj
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
suraj.head(2)
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
# 3943  Facebook   SOCIAL     4.1  78128208.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social     3-Aug-18
# 3943  1,000,000,000+  Free     0           Teen  Social     3-Aug-18
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device
# 3943  Varies with device  Varies with device

# %%
suraj.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: category
# Categories (6002, object): [0, 1, 10, 100, ..., 9971, 9975, 999, 9992]

# %%
 suraj.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
suraj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 592.9+ KB

# %%
suraj['App']=suraj['Reviews'].astype('category')

# %%
suraj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  category
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  category
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: category(2), float64(1), object(10)
# memory usage: 789.5+ KB

# %%
suraj['Reviews']=suraj['Reviews'].apply(lambda x:x.replace('M','')).astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-1621b1319d9e> in <module>
# ----> 1 suraj['Reviews']=suraj['Reviews'].apply(lambda x:x.replace('M','')).astype('float')
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-135-1621b1319d9e> in <lambda>(x)
# ----> 1 suraj['Reviews']=suraj['Reviews'].apply(lambda x:x.replace('M','')).astype('float')
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
suraj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  category
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: category(1), float64(2), object(10)
# memory usage: 733.5+ KB

# %%
suraj
# Out:
#           App             Category  Rating Reviews                Size  \
# 0         159       ART_AND_DESIGN     4.1     159                 19M
# 1         967       ART_AND_DESIGN     3.9     967                 14M
# 2       87510       ART_AND_DESIGN     4.7   87510                8.7M
# 3      215644       ART_AND_DESIGN     4.5  215644                 25M
# 4         967       ART_AND_DESIGN     4.3     967                2.8M
# ...       ...                  ...     ...     ...                 ...
# 10836      38               FAMILY     4.5      38                 53M
# 10837       4               FAMILY     5.0       4                3.6M
# 10838       3              MEDICAL     NaN       3                9.5M
# 10839     114  BOOKS_AND_REFERENCE     4.5     114  Varies with device
# 10840  398307            LIFESTYLE     4.5  398307                 19M
#
#           Installs  Type Price Content Rating                     Genres  \
# ...

# %%
suraj.Rating.mean()
# Out:
# 4.193338315362448

# %%
suraj['Rating'].mean()
# Out:
# 4.193338315362448

# %%
len(suraj['Type'])
# Out:
# 10841

# %%
def ntrue(Type):
    c=0
    n=len(suraj['Type'])
    for i in range(n):
        if Type=='True':
            c=c+1
    return c

# %%
suraj['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
suraj[suraj['Category']=='PHOTOGRAPHY']['Rating'].mean()
# Out:
# 4.192113564668767

# %%
suraj
# Out:
#           App             Category  Rating   Reviews                Size  \
# 0         159       ART_AND_DESIGN     4.1     159.0                 19M
# 1         967       ART_AND_DESIGN     3.9     967.0                 14M
# 2       87510       ART_AND_DESIGN     4.7   87510.0                8.7M
# 3      215644       ART_AND_DESIGN     4.5  215644.0                 25M
# 4         967       ART_AND_DESIGN     4.3     967.0                2.8M
# ...       ...                  ...     ...       ...                 ...
# 10836      38               FAMILY     4.5      38.0                 53M
# 10837       4               FAMILY     5.0       4.0                3.6M
# 10838       3              MEDICAL     NaN       3.0                9.5M
# 10839     114  BOOKS_AND_REFERENCE     4.5     114.0  Varies with device
# 10840  398307            LIFESTYLE     4.5  398307.0                 19M
#
#           Installs  Type Price Content Rating                     Genres  \
# ...

# %%
suraj['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
(suraj[suraj['Type']=='Free'])
# Out:
#                                                     App           Category  \
# 2544                                           Facebook             SOCIAL
# 3943                                           Facebook             SOCIAL
# 381                                  WhatsApp Messenger      COMMUNICATION
# 336                                  WhatsApp Messenger      COMMUNICATION
# 3904                                 WhatsApp Messenger      COMMUNICATION
# ...                                                 ...                ...
# 8501                               DK Childcare Centers          LIFESTYLE
# 2460                                    Drug Calculator            MEDICAL
# 9713                                          eP Finder  AUTO_AND_VEHICLES
# 8495                                     HDWallpaper DK    PERSONALIZATION
# 5086  Apps for SportsBєtting.ag - Bitcoin Welcome here!             SPORTS
#
# ...

# %%
len(suraj[suraj['Type']=='Paid'])
# Out:
# 800

# %%
suraj['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
suraj.sort_values(by='Reviews',ascending=False).head(1)
# Out:
#                          App Category  Rating Reviews Size    Installs  Type  \
# 2989  GollerCepte Live Score   SPORTS     4.2    9992  31M  1,000,000+  Free
#
#      Price Content Rating  Genres Last Updated Current Ver Android Ver
# 2989     0       Everyone  Sports    23-May-18         6.5  4.1 and up

# %%
suraj.head(2545)
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 2540                       PatientPORTAL by InteliChart         MEDICAL
# 2541                   Hypertension High blood pressure         MEDICAL
# 2542                                         Fever Care         MEDICAL
# 2543                         1800 Contacts - Lens Store         MEDICAL
# 2544                                           Facebook          SOCIAL
#
#       Rating   Reviews                Size        Installs  Type Price  \
# ...

# %%
suraj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 592.9+ KB

# %%
suraj
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
suraj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 635.3+ KB

# %%
suraj=suraj.sort_values(by='Reviews',ascending=False)

# %%
suraj[suraj['Reviews']==suraj['Reviews'].max()]
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social     3-Aug-18
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %%
suraj.sort_values(by='Reviews',ascending=False).head(5)
# Out:
#                      App       Category  Rating     Reviews  \
# 2544            Facebook         SOCIAL     4.1  78158306.0
# 3943            Facebook         SOCIAL     4.1  78128208.0
# 381   WhatsApp Messenger  COMMUNICATION     4.4  69119316.0
# 336   WhatsApp Messenger  COMMUNICATION     4.4  69119316.0
# 3904  WhatsApp Messenger  COMMUNICATION     4.4  69109672.0
#
#                     Size        Installs  Type Price Content Rating  \
# 2544  Varies with device  1,000,000,000+  Free     0           Teen
# 3943  Varies with device  1,000,000,000+  Free     0           Teen
# 381   Varies with device  1,000,000,000+  Free     0       Everyone
# 336   Varies with device  1,000,000,000+  Free     0       Everyone
# 3904  Varies with device  1,000,000,000+  Free     0       Everyone
#
#              Genres Last Updated         Current Ver         Android Ver
# 2544         Social     3-Aug-18  Varies with device  Varies with device
# ...

# %%
suraj
# Out:
#                                                     App           Category  \
# 2544                                           Facebook             SOCIAL
# 3943                                           Facebook             SOCIAL
# 381                                  WhatsApp Messenger      COMMUNICATION
# 336                                  WhatsApp Messenger      COMMUNICATION
# 3904                                 WhatsApp Messenger      COMMUNICATION
# ...                                                 ...                ...
# 9713                                          eP Finder  AUTO_AND_VEHICLES
# 8495                                     HDWallpaper DK    PERSONALIZATION
# 6277                                   Bi-Tank Ads Free               GAME
# 8489                               DK Primrose for KLWP    PERSONALIZATION
# 5086  Apps for SportsBєtting.ag - Bitcoin Welcome here!             SPORTS
#
# ...

# %%
suraj.sort_values(by='Installs',ascending=False)
# Out:
#                                                 App          Category  Rating  \
# 10472       Life Made WI-Fi Touchscreen Photo Frame               1.9    19.0
# 4147                   Gboard - the Google Keyboard             TOOLS     4.2
# 1662                                            Pou              GAME     4.3
# 4566                     SHAREit - Transfer & Share             TOOLS     4.6
# 3255                     SHAREit - Transfer & Share             TOOLS     4.6
# ...                                             ...               ...     ...
# 7434                                  Pekalongan CJ            SOCIAL     NaN
# 9337                       EG | Explore Folegandros  TRAVEL_AND_LOCAL     NaN
# 4465   Popsicle Launcher for Android P 9.0 launcher   PERSONALIZATION     NaN
# 9905                                    Eu sou Rico           FINANCE     NaN
# 9148                      Command & Conquer: Rivals            FAMILY     NaN
#
# ...

# %%
suraj['Installs']=suraj['Installs'].apply(lambda x:x.replace('+','').replace(",",""))

# %%
suraj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 677.5+ KB

# %%
suraj['Installs'].astype('float')
# Out:
# 0           10000.0
# 1          500000.0
# 2         5000000.0
# 3        50000000.0
# 4          100000.0
#             ...
# 10836        5000.0
# 10837         100.0
# 10838        1000.0
# 10839        1000.0
# 10840    10000000.0
# Name: Installs, Length: 10840, dtype: float64

# %%
suraj['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0', 'Free'],
#       dtype=object)

# %%
suraj[suraj['Installs']=='Free']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
suraj.drop(labels=10472,axis=0,inplace=True)

# %%
suraj.sort_values(by='Installs',ascending=False).head()
# Out:
#                                                     App            Category  \
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 474                         LINE: Free Calls & Messages       COMMUNICATION
# 5596                                     Samsung Health  HEALTH_AND_FITNESS
# 371               Google Duo - High Quality Video Calls       COMMUNICATION
# 3767                       Flipboard: News For Our Time  NEWS_AND_MAGAZINES
#
#       Rating   Reviews                Size   Installs  Type Price  \
# 7536     4.7  24900999  Varies with device  500000000  Free     0
# 474      4.2  10790289  Varies with device  500000000  Free     0
# 5596     4.3    480208                 70M  500000000  Free     0
# 371      4.6   2083237  Varies with device  500000000  Free     0
# 3767     4.4   1284017  Varies with device  500000000  Free     0
#
#      Content Rating            Genres Last Updated               Current Ver  \
# ...

# %%
suraj['Installs']=suraj['Installs'].astype('float')

# %%
suraj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  object
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  float64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 719.8+ KB

# %%
suraj.sort_values(by='Installs',ascending=False).head()
# Out:
#                                            App       Category  Rating  \
# 3896                            Subway Surfers           GAME     4.5
# 3943                                  Facebook         SOCIAL     4.1
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 3523                              Google Drive   PRODUCTIVITY     4.4
# 3565                              Google Drive   PRODUCTIVITY     4.4
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# 3896  27711703                 76M  1.000000e+09  Free     0   Everyone 10+
# 3943  78128208  Varies with device  1.000000e+09  Free     0           Teen
# 335   56642847  Varies with device  1.000000e+09  Free     0       Everyone
# 3523   2731211  Varies with device  1.000000e+09  Free     0       Everyone
# 3565   2731211  Varies with device  1.000000e+09  Free     0       Everyone
#
#              Genres Last Updated         Current Ver         Android Ver
# ...

# %%
suraj
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pd.options.display.max_columns
# Out:
# 7

# %%
pd.options.display.max_rows=5

# %%
 suraj
# Out:
#                                                   App             Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                 Coloring book moana       ART_AND_DESIGN
# ...                                               ...                  ...
# 10839                   The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840   iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  ... Last Updated         Current Ver         Android Ver
# 0         4.1  ...     7-Jan-18               1.0.0        4.0.3 and up
# 1         3.9  ...    15-Jan-18               2.0.0        4.0.3 and up
# ...       ...  ...          ...                 ...                 ...
# 10839     4.5  ...    19-Jan-15  Varies with device  Varies with device
# 10840     4.5  ...    25-Jul-18  Varies with device  Varies with device
#
# [10840 rows x 13 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.reset_option('max_rows')

# %%
pd.get_option('max_row')
# Out:
# 20

# %%
pd.set_option('max_row',20)

# %%
pd.describe_option('max_row')
# Out:
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]

# %%
suraj
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pd.options.display.precision
# Out:
# 6

# %%
pd.reset_option('precision')
